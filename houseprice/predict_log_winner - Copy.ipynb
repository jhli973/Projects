# %% [markdown]
# This is capston project for my udacity ML nanodegree project
#
# You can find the data information from [kaggle](https://www.kaggle.com/c/house-prices-advanced-regression-techniques) and more detailed from [here](https://ww2.amstat.org/publications/jse/v19n3/decock/DataDocumentation.txt). The data contains 23 nominal, 23 ordinal, 14 discrete, 20 continuous variables and one target variable.
#
# Helpful information from [Adam Massachi blog](https://www.dataquest.io/blog/kaggle-getting-started/)

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

pd.set_option('display.max_columns', None)

# %%
train = pd.read_csv('train.csv')
train.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
# check the dimension
print(train.shape)
# Out:
# (1460, 81)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
# Id               1460 non-null int64
# MSSubClass       1460 non-null int64
# MSZoning         1460 non-null object
# LotFrontage      1201 non-null float64
# LotArea          1460 non-null int64
# Street           1460 non-null object
# Alley            91 non-null object
# LotShape         1460 non-null object
# LandContour      1460 non-null object
# Utilities        1460 non-null object
# LotConfig        1460 non-null object
# LandSlope        1460 non-null object
# Neighborhood     1460 non-null object
# Condition1       1460 non-null object
# Condition2       1460 non-null object
# BldgType         1460 non-null object
# HouseStyle       1460 non-null object
# OverallQual      1460 non-null int64
# OverallCond      1460 non-null int64
# YearBuilt        1460 non-null int64
# YearRemodAdd     1460 non-null int64
# RoofStyle        1460 non-null object
# ...

# %%
test = pd.read_csv('test.csv')
print(test.shape)
# Out:
# (1459, 80)

# %%
train.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726
# std       1.112799    30.202904     20.645407   181.066207   456.098091
# ...

# %%
categoricals = train.select_dtypes(exclude=[np.number])
categoricals.describe()
# Out:
#        MSZoning Street Alley LotShape LandContour Utilities LotConfig  \
# count      1460   1460    91     1460        1460      1460      1460
# unique        5      2     2        4           4         2         5
# top          RL   Pave  Grvl      Reg         Lvl    AllPub    Inside
# freq       1151   1454    50      925        1311      1459      1052
#
#        LandSlope Neighborhood Condition1 Condition2 BldgType HouseStyle  \
# count       1460         1460       1460       1460     1460       1460
# unique         3           25          9          8        5          8
# top          Gtl        NAmes       Norm       Norm     1Fam     1Story
# freq        1382          225       1260       1445     1220        726
#
#        RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType ExterQual  \
# count       1460     1460        1460        1460       1452      1460
# unique         6        8          15          16          4         4
# ...

# %% [markdown]
# ## Check Missing Values

# %%
# check the missing values in each feature
s = train.apply(lambda x: sum(x.isnull()), axis=0)
miss = s[s>0].sort_values(ascending=False)
print(miss)
# Out:
# PoolQC          1453
# MiscFeature     1406
# Alley           1369
# Fence           1179
# FireplaceQu      690
# LotFrontage      259
# GarageYrBlt       81
# GarageType        81
# GarageFinish      81
# GarageQual        81
# GarageCond        81
# BsmtFinType2      38
# BsmtExposure      38
# BsmtFinType1      37
# BsmtCond          37
# BsmtQual          37
# MasVnrArea         8
# MasVnrType         8
# Electrical         1
# dtype: int64

# %% [markdown]
# ## Check unique values for each categorical feature

# %%
categorical_cols = []
for col, col_data in train.iteritems():
    if col_data.dtype == object:
        categorical_cols.append(col) 
        
for col in categorical_cols:
        print(col, train[col].unique())
# Out:
# ('MSZoning', array(['RL', 'RM', 'C (all)', 'FV', 'RH'], dtype=object))
# ('Street', array(['Pave', 'Grvl'], dtype=object))
# ('Alley', array([nan, 'Grvl', 'Pave'], dtype=object))
# ('LotShape', array(['Reg', 'IR1', 'IR2', 'IR3'], dtype=object))
# ('LandContour', array(['Lvl', 'Bnk', 'Low', 'HLS'], dtype=object))
# ('Utilities', array(['AllPub', 'NoSeWa'], dtype=object))
# ('LotConfig', array(['Inside', 'FR2', 'Corner', 'CulDSac', 'FR3'], dtype=object))
# ('LandSlope', array(['Gtl', 'Mod', 'Sev'], dtype=object))
# ('Neighborhood', array(['CollgCr', 'Veenker', 'Crawfor', 'NoRidge', 'Mitchel', 'Somerst',
#        'NWAmes', 'OldTown', 'BrkSide', 'Sawyer', 'NridgHt', 'NAmes',
#        'SawyerW', 'IDOTRR', 'MeadowV', 'Edwards', 'Timber', 'Gilbert',
#        'StoneBr', 'ClearCr', 'NPkVill', 'Blmngtn', 'BrDale', 'SWISU',
#        'Blueste'], dtype=object))
# ('Condition1', array(['Norm', 'Feedr', 'PosN', 'Artery', 'RRAe', 'RRNn', 'RRAn', 'PosA',
#        'RRNe'], dtype=object))
# ...

# %%
print(train['MasVnrType'].value_counts())
mvt_dummies = pd.get_dummies(train['MasVnrType']) #,drop_first=True)
print(mvt_dummies.sum())
# Out:
# None       864
# BrkFace    445
# Stone      128
# BrkCmn      15
# Name: MasVnrType, dtype: int64
# BrkCmn      15.0
# BrkFace    445.0
# None       864.0
# Stone      128.0
# dtype: float64

# %% [markdown]
# ## Check the distribution of target variable

# %%
y = train.iloc[:,80]

# %%
sns.set(rc={"figure.figsize": (8,6)})
sns.distplot(y,hist=True, kde=False, bins=50);

# %% [markdown]
# ### Since the target variable is skewed, we will transform the data using numpy log #1p.

# %% [markdown]
# ## Visualize Continuous features (exclude the ID)

# %%
numeric_cols = []

for col, col_data in train.iteritems():
    if col_data.dtype != object and col!='Id':
        numeric_cols.append(col)
        
n_cols = 4
n_rows = 9
idx = 0
for i in range(n_rows):
    fg, ax = plt.subplots(nrows=1, ncols = n_cols, figsize=(12,3))
    for j in range(n_cols):
        sns.violinplot(y=train[numeric_cols[idx]], ax=ax[j])
        idx += 1
        if idx >= 36:
            break

# %% [markdown]
# **Highly skewed features: **
#
#     - LotArea
#     - BsmtFinSF2
#     - LowQualFinSF
#     - 3SsnPorch
#     - PoolArea
#     - MiscVal

# %%
from scipy.stats import skew
#print(train.columns)

for col in numeric_cols:
    if skew(train[col]) >= 4:
        print(col, skew(train[col]))
# Out:
# ('LotArea', 12.195142125084478)
# ('BsmtFinSF2', 4.250888017057445)
# ('LowQualFinSF', 9.002080417658552)
# ('BsmtHalfBath', 4.0991856695420035)
# ('KitchenAbvGr', 4.483784093860484)
# ('3SsnPorch', 10.293752357165413)
# ('ScreenPorch', 4.1179773827954875)
# ('PoolArea', 14.813134660429398)
# ('MiscVal', 24.4516396173223)

# %% [markdown]
# ### Check the correlation between the numeric features and target

# %%
numerics = train.select_dtypes(include=[np.number])
numerics.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726
# std       1.112799    30.202904     20.645407   181.066207   456.098091
# ...

# %%
corr = numerics.corr()
top_10_corr = corr['SalePrice'].sort_values(ascending=False)[1:11]
print(top_10_corr)
# Out:
# OverallQual     0.790982
# GrLivArea       0.708624
# GarageCars      0.640409
# GarageArea      0.623431
# TotalBsmtSF     0.613581
# 1stFlrSF        0.605852
# FullBath        0.560664
# TotRmsAbvGrd    0.533723
# YearBuilt       0.522897
# YearRemodAdd    0.507101
# Name: SalePrice, dtype: float64

# %%
last_10_corr = corr['SalePrice'].sort_values(ascending=False)[-10:]
print(last_10_corr)
# Out:
# BsmtFinSF2      -0.011378
# BsmtHalfBath    -0.016844
# MiscVal         -0.021190
# Id              -0.021917
# LowQualFinSF    -0.025606
# YrSold          -0.028923
# OverallCond     -0.077856
# MSSubClass      -0.084284
# EnclosedPorch   -0.128578
# KitchenAbvGr    -0.135907
# Name: SalePrice, dtype: float64

# %% [markdown]
# ## Visualize Categorical features

# %%
n_cols = 4
n_rows = 11
idx = 0
for i in range(n_rows):
    fg,ax = plt.subplots(nrows=1,ncols=n_cols,sharey=True,figsize=(12, 3))
    for j in range(n_cols):
        sns.countplot(x=train[categorical_cols[idx]], ax=ax[j])
        idx += 1
        if idx >= 43:
            break

# %% [markdown]
# **Lack of Variation**
#
# - Utilities

# %%
n_cols = 4
n_rows = 4
idx = 0

no_none_categorical_cols = []
high_level_cols = ['Neighborhood','Exterior1st','Functional', 'RoofStyle', 'Exterior2nd', 'RoofMatl','SaleCondition', 'SaleType', 'Condition1' ,'Condition2', 'HouseStyle']
for col in categorical_cols:
    if col not in miss.index and col not in high_level_cols:
        no_none_categorical_cols.append(col)
    else:
        pass

for i in range(n_rows):
    fg,ax = plt.subplots(nrows=1,ncols=n_cols,sharey=True,figsize=(14, 4))
    for j in range(n_cols):
        col = no_none_categorical_cols[idx]
        levels = train[['SalePrice', col]].groupby([col], as_index=False).mean().sort_values(by='SalePrice', ascending=False)[col]
        sns.barplot(x=col, y = 'SalePrice', data=train,order = levels, ax=ax[j])
        idx += 1
        if idx >= 16:
            break

# %%
n_cols = 2
n_rows = 4
idx = 0

median_level_cols = [ 'RoofStyle','SaleCondition', 'SaleType', 'Condition1' ,'Condition2', 'HouseStyle', 'Functional', 'RoofStyle']

for i in range(n_rows):
    fg,ax = plt.subplots(nrows=1,ncols=n_cols,sharey=True,figsize=(14, 4))
    for j in range(n_cols):
        col = median_level_cols[idx]
        levels = train[['SalePrice', col]].groupby([col], as_index=False).mean().sort_values(by='SalePrice', ascending=False)[col]
        sns.barplot(x=col, y = 'SalePrice', data=train,order = levels, ax=ax[j])
        idx += 1
        if idx >= 8:
            break

# %%
n_cols = 1
n_rows = 2
idx = 0

high_level_cols = ['Exterior1st', 'Exterior2nd']

for i in range(n_rows):
    fg,ax = plt.subplots(nrows=1,ncols=n_cols,sharey=True,figsize=(14, 4))
    col = high_level_cols[idx]

    levels = train[['SalePrice', col]].groupby([col], as_index=False).mean().sort_values(by='SalePrice', ascending=False)[col]
    sns.barplot(x=col, y = 'SalePrice', data=train, order=levels)
    idx += 1
    if idx >= 2:
        break

# %%
plt.figure(figsize=(18,7))
levels = train[['SalePrice','Neighborhood']].groupby(['Neighborhood'],
                as_index=False).mean().sort_values(by='SalePrice',ascending=False).Neighborhood
sns.barplot(x='Neighborhood', y = 'SalePrice', data=train, order=levels)

# %% [markdown]
# ## Scatter plot of target and predict continuous variables

# %%
from scipy.stats import boxcox

y = np.log(y)

sns.set(rc={"figure.figsize": (10, 8)})
sns.distplot(y,hist=True, kde=False, bins=50)

# %%
fig = plt.figure(figsize=(22, 10))

for i, col in enumerate(top_10_corr.index):
    if col != 'SalePrice':
        plt.subplot(3, 4, i + 1)  

        plt.plot(train[col], y, 'o')
        plt.xlabel(col)
        plt.ylabel('prices')

# %%
fig = plt.figure(figsize=(22, 10))

for i, col in enumerate(last_10_corr.index):
    if col != 'SalePrice':
        plt.subplot(3, 4, i + 1)  

        plt.plot(train[col], y, 'o')
        plt.xlabel(col)
        plt.ylabel('prices')

# %% [markdown]
# **Highly correlated variables with prices**
#
# - OverallQual
# - TotalBsmtSF
# - 1stFlrSF
# - GrLiveArea
#
# But there are several outliers

# %%
train[train['TotalBsmtSF'] > 6000]
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1298  1299          60       RL        313.0    63887   Pave   NaN      IR3
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 1298         Bnk    AllPub    Corner       Gtl      Edwards      Feedr
#
#      Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 1298       Norm     1Fam     2Story           10            5       2008
#
#       YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 1298          2008       Hip  ClyTile      Stucco      Stucco      Stone
#
#       MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond  \
# 1298       796.0        Ex        TA      PConc       Ex       TA
#
#      BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  \
# 1298           Gd          GLQ        5644          Unf           0
#
#       BsmtUnfSF  TotalBsmtSF Heating HeatingQC CentralAir Electrical  \
# ...

# %%
train[((train['GarageArea'] > 1200 ) & (train['SalePrice'] < 200000))]
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1061  1062          30  C (all)        120.0    18000   Grvl   NaN      Reg
# 1190  1191         190       RL          NaN    32463   Pave   NaN      Reg
# 1298  1299          60       RL        313.0    63887   Pave   NaN      IR3
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 1061         Low    AllPub    Inside       Gtl       IDOTRR       Norm
# 1190         Low    AllPub    Inside       Mod      Mitchel       Norm
# 1298         Bnk    AllPub    Corner       Gtl      Edwards      Feedr
#
#      Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 1061       Norm     1Fam     1Story            3            4       1935
# 1190       Norm   2fmCon     1Story            4            4       1961
# 1298       Norm     1Fam     2Story           10            5       2008
#
#       YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# ...

# %%
train[train['GrLivArea'] > 4000]
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 523    524          60       RL        130.0    40094   Pave   NaN      IR1
# 691    692          60       RL        104.0    21535   Pave   NaN      IR1
# 1182  1183          60       RL        160.0    15623   Pave   NaN      IR1
# 1298  1299          60       RL        313.0    63887   Pave   NaN      IR3
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 523          Bnk    AllPub    Inside       Gtl      Edwards       PosN
# 691          Lvl    AllPub    Corner       Gtl      NoRidge       Norm
# 1182         Lvl    AllPub    Corner       Gtl      NoRidge       Norm
# 1298         Bnk    AllPub    Corner       Gtl      Edwards      Feedr
#
#      Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 523        PosN     1Fam     2Story           10            5       2007
# 691        Norm     1Fam     2Story           10            6       1994
# ...

# %%
train[train['KitchenAbvGr'] ==0]
# Out:
#       Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 954  955          90       RL         35.0     9400   Pave   NaN      IR1
#
#     LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 954         Lvl    AllPub   CulDSac       Gtl      Edwards       Norm
#
#     Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 954       Norm   Duplex     SFoyer            6            5       1975
#
#      YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 954          1975      Flat  Tar&Grv     WdShing     Plywood    BrkFace
#
#      MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond BsmtExposure  \
# 954       250.0        TA        TA     CBlock       Gd       Gd           Gd
#
#     BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# 954          GLQ         945          Unf           0          0          945
#
# ...

# %%
train[((train['SalePrice'] <= 40000 ) | (train['SalePrice'] > 700000))]
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 30      31          70  C (all)         50.0     8500   Pave  Pave      Reg
# 495    496          30  C (all)         60.0     7879   Pave   NaN      Reg
# 533    534          20       RL         50.0     5000   Pave   NaN      Reg
# 691    692          60       RL        104.0    21535   Pave   NaN      IR1
# 916    917          20  C (all)         50.0     9000   Pave   NaN      Reg
# 968    969          50       RM         50.0     5925   Pave   NaN      Reg
# 1182  1183          60       RL        160.0    15623   Pave   NaN      IR1
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 30           Lvl    AllPub    Inside       Gtl       IDOTRR      Feedr
# 495          Lvl    AllPub    Inside       Gtl       IDOTRR       Norm
# 533          Low    AllPub    Inside       Mod      BrkSide       Norm
# 691          Lvl    AllPub    Corner       Gtl      NoRidge       Norm
# ...

# %% [markdown]
# ## Check the feature correlation more than 0.8 or less than -0.8

# %%
train_corr = train.iloc[:,1:-1].corr()
train_corr.shape[0]
for i in range(train_corr.shape[0]-1, 0, -1):
    for j in range(0, train_corr.shape[0]):
        if i < j and (train_corr.iloc[i,j] >= 0.8  or train_corr.iloc[i,j] <= -0.8):
            print("The correlation between {} and {} is {}".format(train.columns[i], \
                                train.columns[j], round(train_corr.iloc[i,j],2)) )
# Out:
# The correlation between MasVnrType and MasVnrArea is 0.88
# The correlation between BldgType and RoofMatl is 0.83
# The correlation between LandSlope and Neighborhood is 0.82
# The correlation between Street and Exterior2nd is 0.83

# %% [markdown]
# ## Impute missing value in categorical variable as 'unknown'

# %%
for col, col_data in train.iteritems():
    if col in categorical_cols: 
        col_data = col_data.fillna('Unk', inplace=True)
        
for col, col_data in test.iteritems():
    if col in categorical_cols: 
        col_data = col_data.fillna('Unk', inplace=True)

# %%
n_cols = 4
n_rows = 4
idx = 0

has_none_categorical_cols =[]
for col in categorical_cols:
    if col in miss.index:
        has_none_categorical_cols.append(col)
    else:
        pass

for i in range(n_rows):
    fg,ax = plt.subplots(nrows=1,ncols=n_cols,sharey=True,figsize=(14, 4))
    for j in range(n_cols):
        col = has_none_categorical_cols[idx]
        levels = train[['SalePrice', col]].groupby([col], as_index=False).mean().sort_values(by='SalePrice', ascending=False)[col]
        sns.barplot(x=col, y = 'SalePrice', data=train,order = levels, ax=ax[j])
        idx += 1
        if idx >= 16:
            break

# %% [markdown]
# ## Remove some outliers and Split data

# %%
# filter TotalBsmtSF >= 6000

train = train[((train['SalePrice'] < 700000 )&(train['SalePrice'] >= 40000 ))]
train = train[train['GrLivArea'] < 4000]
train = train[train['1stFlrSF'] < 3000]
train = train[train['KitchenAbvGr'] !=0]
train = train[((train['YearRemodAdd']<=1970)&(train['SalePrice'] <= 370000 ))|(train['YearRemodAdd']>1970)]
y = train.iloc[:,80] 
train= train.iloc[:, :80]
train = train.drop(['Utilities', 'Id'], axis=1)
train.shape
# Out:
# (1449, 78)

# %%
train_y = np.log(y)
"""
from scipy.stats import boxcox

train_y, lambda_ = boxcox(y)
"""
sns.set(rc={"figure.figsize": (10, 8)})
sns.distplot(train_y,hist=True, kde=False, bins=50)

# %%
# testhttp://localhost:8888/notebooks/ml_sandbox/houseprice/predict_lr.ipynb#
ID = test['Id']
test = test.drop(['Utilities', 'Id'], axis=1)
test.shape
# Out:
# (1459, 78)

# %% [markdown]
# ## Group levels of categorical variables

# %%
full_data = [train, test]
for dataset in full_data:
    dataset['Fence'] = dataset['Fence'].replace(['Unk', 'GdPrv'], 'Good')
    dataset['Fence'] = dataset['Fence'].replace(['MnPrv', 'GdWo', 'MnWw'], 'Bad')
    
    dataset['GarageCond'] = dataset['GarageCond'].replace(['TA', 'Gd'], 'Good')
    dataset['GarageCond'] = dataset['GarageCond'].replace(['Ex', 'Fa', 'Po', 'Unk'], 'Bad')
    
    dataset['MiscFeature'] = dataset['MiscFeature'].replace(['Shed', 'Gar2', 'Unk'], 'Ugs')

# %% [markdown]
# ## Impute missing value in numeric variable using default interpolate

# %%
train_num = train.select_dtypes(include=[np.number]).interpolate() 
##train = train.select_dtypes(include=[np.number]).interpolate().dropna()
print(train_num.shape)

test_num = test.select_dtypes(include=[np.number]).interpolate() 
print(test_num.shape)
# Out:
# (1449, 36)
# (1459, 36)

# %%
X_train = train_num

Y_train = train_y
X_test = test_num

# %% [markdown]
# ## Convert Categorical variables to dummy variables - One Hot Encoding

# %%
"""
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder

dummy_train = []
dummy_test = []
labels = []
for idx, col in enumerate(categorical_cols):
    
    labels = list(set(train_X[col].unique()) | set(test[col].unique()))
    
    # label encode
    label_encoder = LabelEncoder()
    label_encoder.fit(labels)
    feature_train = label_encoder.transform(train_X[col])
    feature_train = feature_train.reshape(train_X.shape[0],1)
    
    feature_test = label_encoder.transform(test[col])
    feature_test = feature_test.reshape(test.shape[0],1)
    
    # one hot encode
    onehot_encoder = OneHotEncoder(sparse=False, n_values=len(labels))
    feature_train = onehot_encoder.fit_transform(feature_train)
    dummy_train.append(feature_train)
    
    feature_test = onehot_encoder.fit_transform(feature_test)
    dummy_test.append(feature_test)
    
# Make a 2D array from a list of 1D arrays
encode_train = np.column_stack(dummy_train)
encode_test = np.column_stack(dummy_test)

print(encode_train.shape)
print(encode_test.shape)

X_train = encode_train
Y_train = train_y
print(X_train.shape)
print(Y_train.size)
X_test = encode_test
"""
# Out:
# '\nfrom sklearn.preprocessing import LabelEncoder\nfrom sklearn.preprocessing import OneHotEncoder\n\ndummy_train = []\ndummy_test = []\nlabels = []\nfor idx, col in enumerate(categorical_cols):\n    \n    labels = list(set(train_X[col].unique()) | set(test[col].unique()))\n    \n    # label encode\n    label_encoder = LabelEncoder()\n    label_encoder.fit(labels)\n    feature_train = label_encoder.transform(train_X[col])\n    feature_train = feature_train.reshape(train_X.shape[0],1)\n    \n    feature_test = label_encoder.transform(test[col])\n    feature_test = feature_test.reshape(test.shape[0],1)\n    \n    # one hot encode\n    onehot_encoder = OneHotEncoder(sparse=False, n_values=len(labels))\n    feature_train = onehot_encoder.fit_transform(feature_train)\n    dummy_train.append(feature_train)\n    \n    feature_test = onehot_encoder.fit_transform(feature_test)\n    dummy_test.append(feature_test)\n    \n# Make a 2D array from a list of 1D arrays\nencode_train = np.column_stac
# ...

# %% [markdown]
# # Test Algorithms

# %%
from sklearn.metrics import mean_absolute_error  # I use this metrics because I don't want put more weight on big error
from sklearn.metrics import r2_score

# %%
# Linear Regressor
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.linear_model import ElasticNet

# non linear regressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR

# ensemble regressor
from sklearn.ensemble import BaggingRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import GradientBoostingRegressor

# other regressor
#from xgboost import XGBRegressor

# %% [markdown]
# ## 1. Tree basee

# %%
# Bagging Regressor
model = BaggingRegressor()
model.fit(X_train, Y_train)

mae = mean_absolute_error(y, np.exp(model.predict(X_train)))
#mae = mean_absolute_error(y, np.power((model.predict(X_train) * lambda_) + 1, 1/lambda_))
print(mae)

# Random Forest Regressor
model = RandomForestRegressor()
model.fit(X_train, Y_train)

mae = mean_absolute_error(y, np.exp(model.predict(X_train)))
print(mae)
''''
# ExtraTreesRegressor
model = ExtraTreesRegressor()
model.fit(X_train, Y_train)

mae = mean_absolute_error(y, np.exp(model.predict(X_train)))
print(mae)
'''
# AdaBoostRegressor
model = AdaBoostRegressor()
model.fit(X_train, Y_train)

mae = mean_absolute_error(y, np.exp(model.predict(X_train)))
print(mae)

# GradientBoostingRegressor
model = GradientBoostingRegressor()
model.fit(X_train, Y_train)

mae = mean_absolute_error(y, np.exp(model.predict(X_train)))
print(mae)
# Out:
# 7534.49457037
# 7596.56129426
# 20708.9850288
# 11274.6894111

# %% [markdown]
# ## Random Forest Regressor

# %%
rf = RandomForestRegressor()
rf.fit(X_train, Y_train)

inv_pred = np.exp(rf.predict(X_train))

rf_result = pd.DataFrame({"pred_values": inv_pred, "true_values": y,
"residule" : (y - inv_pred)})
rf_result.plot(x="pred_values", y = "true_values", kind = 'scatter')
rf_result.plot(x="pred_values", y = "residule", kind = 'scatter')

# %%
## predict the test

inv_pred = np.exp(rf.predict(X_test))
rf_pred = pd.DataFrame({'Id':ID, 'SalePrice':inv_pred })
rf_pred.to_csv('sample_submission_rf_boxcox.csv' , index = False)

# %% [markdown]
# ## Gradient Boosting Regressor

# %%
gbr = GradientBoostingRegressor()
gbr.fit(X_train, Y_train)

inv_pred = np.exp(gbr.predict(X_train))

gbr_result = pd.DataFrame({"pred_values":inv_pred, "true_values":y,
"residule" : (y - inv_pred)})
gbr_result.plot(x="pred_values", y = "true_values", kind = 'scatter')
gbr_result.plot(x="pred_values", y = "residule", kind = 'scatter')

# %%
inv_pred = np.exp(gbr.predict(X_test))

gbr_pred = pd.DataFrame({'Id':ID, 'SalePrice':inv_pred })
gbr_pred
gbr_pred.to_csv('sample_submission_gbr_boxcox.csv', index = False)

# %% [markdown]
# ## AdaBoost Regressor

# %%
# AdaBoost Regressor
ad = AdaBoostRegressor()
ad.fit(X_train, Y_train)

inv_pred = np.exp(ad.predict(X_train))

ad_result = pd.DataFrame({"pred_values":inv_pred, "true_values":y,
"residule" : (y - inv_pred)})
ad_result.plot(x="pred_values", y = "true_values", kind = 'scatter')
ad_result.plot(x="pred_values", y = "residule", kind = 'scatter')

# %%
inv_pred = np.exp(ad.predict(X_test))

ad_pred = pd.DataFrame({'Id':ID, 'SalePrice':inv_pred })
ad_pred
ad_pred.to_csv('sample_submission_ad_boxcox.csv', index = False)

# %%
from sklearn.feature_selection import RFE
rfe = RFE(gbr, 15)
rfe = rfe.fit(X_train, Y_train)
print(rfe.support_)
print(rfe.ranking_)

rfe = RFE(ad, 15)
rfe = rfe.fit(X_train, Y_train)
print(rfe.support_)
print(rfe.ranking_)

rfe = RFE(rf, 15)
rfe = rfe.fit(X_train, Y_train)
print(rfe.support_)
print(rfe.ranking_)
# Out:
# [False False  True  True  True  True  True False  True False  True  True
#   True  True False  True False False False False False False False False
#   True False  True  True False False False  True False False False False]
# [13  7  1  1  1  1  1 11  1  6  1  1  1  1 14  1  5 22 19 15 20 12 16  3  1
#  17  1  1  4 10 21  1  9 18  2  8]
# [False False  True  True  True  True  True False  True False False  True
#   True False False  True  True False False False False False  True False
#   True  True  True  True False False False False False False False False]
# [22  6  1  1  1  1  1 12  1 13  5  1  1 11 14  1  1 20 21  7  8 15  1  2  1
#   1  1  1 10  4 16 18 19 17  9  3]
# [False  True  True  True  True  True  True False  True False  True  True
#   True  True False  True False False False False False False False False
#   True  True  True False False False False False False False False False]
# [ 7  1  1  1  1  1  1 10  1 19  1  1  1  1 21  1 13 17 11 14 12 18  6  3  1
# ...

# %%
cols = X_train.columns
idx = [2, 3, 4, 5, 6, 8,  11, 12, 15,  24, 26]
selected_features = []
for i in idx:
    selected_features.append(cols[i])
print(selected_features)
# Out:
# ['LotArea', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'BsmtFinSF1', 'TotalBsmtSF', '1stFlrSF', 'GrLivArea', 'GarageYrBlt', 'GarageArea']

# %%
X_train_11 = X_train[selected_features]
X_train_11.head()
# Out:
#    LotArea  OverallQual  OverallCond  YearBuilt  YearRemodAdd  BsmtFinSF1  \
# 0     8450            7            5       2003          2003         706
# 1     9600            6            8       1976          1976         978
# 2    11250            7            5       2001          2002         486
# 3     9550            7            5       1915          1970         216
# 4    14260            8            5       2000          2000         655
#
#    TotalBsmtSF  1stFlrSF  GrLivArea  GarageYrBlt  GarageArea
# 0          856       856       1710       2003.0         548
# 1         1262      1262       1262       1976.0         460
# 2          920       920       1786       2001.0         608
# 3          756       961       1717       1998.0         642
# 4         1145      1145       2198       2000.0         836

# %%
gbr = GradientBoostingRegressor()
rf = RandomForestRegressor()
rf.fit(X_train_11, Y_train)

inv_pred = np.exp(rf.predict(X_train_11))

gbr_result = pd.DataFrame({"pred_values":inv_pred, "true_values":y,
"residule" : (y - inv_pred)})
gbr_result.plot(x="pred_values", y = "true_values", kind = 'scatter')
gbr_result.plot(x="pred_values", y = "residule", kind = 'scatter')

# %%
mae = mean_absolute_error(y, np.exp(rf.predict(X_train_11)))
print(mae)
# Out:
# 7605.38161875

# %%
X_test_11 = X_test[selected_features]

inv_pred = np.exp(rf.predict(X_test_11))

gbr_pred = pd.DataFrame({'Id':ID, 'SalePrice':inv_pred })
gbr_pred
gbr_pred.to_csv('sample_submission_gbr_11_log.csv', index = False)

# %%
# box cox 
from scipy import stats
y = np.array([  10000.,  290000.,  430000.,  210000.])
bc_y, lam = stats.boxcox(y)

# inverse box cox function
in_y = np.power((bc_y * lam)+1, 1/lam)
in_y
# Out:
# array([  10000.,  290000.,  430000.,  210000.])

# %%
print(lam)
# Out:
# 0.690998531572

# %%
s = pd.Series([0, 1, np.nan,4,7,5, np.nan,3])
s.interpolate()
# Out:
# 0    0.0
# 1    1.0
# 2    2.5
# 3    4.0
# 4    7.0
# 5    5.0
# 6    4.0
# 7    3.0
# dtype: float64

# %%
s = pd.DataFrame({'animal':['monkey', 'bull', np.nan, 'chicken', 'dog', np.nan, 'bull', 'cow'],'Number':[0, 1, np.nan,4,7,5, np.nan,3]} )
s
# Out:
#    Number   animal
# 0     0.0   monkey
# 1     1.0     bull
# 2     NaN      NaN
# 3     4.0  chicken
# 4     7.0      dog
# 5     5.0      NaN
# 6     NaN     bull
# 7     3.0      cow

# %%
s = s.interpolate()
print(s)
# Out:
#    Number   animal
# 0     0.0   monkey
# 1     1.0     bull
# 2     2.5      NaN
# 3     4.0  chicken
# 4     7.0      dog
# 5     5.0      NaN
# 6     4.0     bull
# 7     3.0      cow

# %% [markdown]
# ```python
# idx_del = []
#
# for idx in data.index:
#     if data.iloc[idx][miss_less_4.index].isnull().any():
#         idx_del.append(idx)
#
# idx_del
# data.iloc[idx_del,]
# ```

# %%
"""
from scipy.stats import boxcox

train_y, lambda_ = boxcox(y)

sns.set(rc={"figure.figsize": (10, 8)})
sns.distplot(train_y,hist=True, kde=False, bins=50)
"""
# Out:
# '\nfrom scipy.stats import boxcox\n\ntrain_y, lambda_ = boxcox(y)\n\nsns.set(rc={"figure.figsize": (10, 8)})\nsns.distplot(train_y,hist=True, kde=False, bins=50)\n'
